# %%
import tensorflow as tf
import numpy as np
from tensorflow.keras.layers import Dense, Flatten, Dropout, Conv2D, MaxPooling2D
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import MobileNet, MobileNetV2
from tensorflow.keras.metrics import BinaryAccuracy
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
# Directory Path
BASE_DIR = 'Dataset2'
print(f"Base Directory: {os.listdir(BASE_DIR)}")

data_train='Dataset2/train'
print(f"Data Directory: {os.listdir(data_train)}")
data_validation='Dataset2/valid'
print(f"Data Directory: {os.listdir(data_validation)}")
# Out:
# Base Directory: ['LokaJamu-7.txt', 'train', 'valid']
# Data Directory: ['Belimbing Sayur', 'Bunga Lawang', 'Jahe', 'Jeruk Nipis', 'Kunyit', 'Lengkuas', 'Mengkudu']
# Data Directory: ['Belimbing Sayur', 'Bunga Lawang', 'Jahe', 'Jeruk Nipis', 'Kunyit', 'Lengkuas', 'Mengkudu']

# %%
# Define constants
BATCH_SIZE = 32  # Set your batch size
NUM_CLASSES = 7  # Set the number of classes
CLASS_MODE='categorical'

# %%
# Data augmentation for training and rescaling for validation
train_datagen = ImageDataGenerator(
    rescale=1/255,
    rotation_range=10,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    vertical_flip=True,
    fill_mode='reflect'
)

test_datagen = ImageDataGenerator(
    rescale=1./255
)

# %%
# Use binary class mode for multi-label classification
train_generator = train_datagen.flow_from_directory(
    data_train,
    target_size=(224, 224),
    batch_size=BATCH_SIZE,
    class_mode=CLASS_MODE # Change to 'binary' for multi-label
)

validation_generator = test_datagen.flow_from_directory(
    data_validation,
    target_size=(224, 224),
    batch_size=BATCH_SIZE,
    class_mode=CLASS_MODE # Change to 'binary' for multi-label
)
# Out:
# Found 2055 images belonging to 7 classes.
# Found 487 images belonging to 7 classes.

# %%
#create model
def based_model():
    model=tf.keras.models.Sequential([
        tf.keras.Input(shape=(224,224,3)),
        tf.keras.layers.Rescaling(1./255),
        tf.keras.layers.Conv2D(16,(3,3), activation='relu'),
        tf.keras.layers.MaxPooling2D(2,2),
        tf.keras.layers.Conv2D(32,(3,3), activation='relu'),
        tf.keras.layers.MaxPooling2D(2,2),
        tf.keras.layers.Conv2D(64,(3,3), activation='relu'),
        tf.keras.layers.MaxPooling2D(2,2),
        tf.keras.layers.Conv2D(128,(3,3), activation='relu'),
        tf.keras.layers.MaxPooling2D(2,2),

        tf.keras.layers.Flatten(),
        
        tf.keras.layers.Dense(256, activation='relu'),
        tf.keras.layers.Dropout(0.2), 
        tf.keras.layers.Dense(NUM_CLASSES, activation='sigmoid')
    ])
    
    model.compile(
        optimizer=tf.keras.optimizers.RMSprop(learning_rate=0.001),
        loss='categorical_crossentropy',
        metrics=['accuracy'] 
    )
    return model

# %%
model = based_model()
model.summary()
# Out:
# Model: "sequential_8"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ rescaling_6 (Rescaling)         │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_27 (Conv2D)              │ (None, 222, 222, 16)   │           448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_27 (MaxPooling2D) │ (None, 111, 111, 16)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_28 (Conv2D)              │ (None, 109, 109, 32)   │         4,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_28 (MaxPooling2D) │ (None, 54, 54, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_29 (Conv2D)              │ (None, 52, 52, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_29 (MaxPooling2D) │ (None, 26, 26, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_30 (Conv2D)              │ (None, 24, 24, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_30 (MaxPooling2D) │ (None, 12, 12, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_8 (Flatten)             │ (None, 18432)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_16 (Dense)                │ (None, 256)            │     4,718,848 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_8 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_17 (Dense)                │ (None, 7)              │         1,799 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,818,087 (18.38 MB)
#  Trainable params: 4,818,087 (18.38 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Compile the model with binary crossentropy loss
model.compile(loss='binary_crossentropy',  # Change to binary_crossentropy
              optimizer=tf.optimizers.Adam(),
              metrics=[BinaryAccuracy()])

# %%
from tensorflow.keras.callbacks import EarlyStopping

early_stopping = EarlyStopping(
    monitor='val_loss',  # Metric yang diamati
    patience=5,          # Epoch tanpa perbaikan sebelum pelatihan dihentikan
    restore_best_weights=True  # Kembalikan bobot terbaik setelah pelatihan berhenti
)

from tensorflow.keras.callbacks import ReduceLROnPlateau

reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',  # Metric yang diamati
    factor=0.1,          # Faktor pengurangan learning rate (misal, dikali 0.1)
    patience=3,          # Epoch tanpa perbaikan sebelum learning rate dikurangi
    min_lr=1e-6          # Batas minimum learning rate
)


# Callbacks
class EarlyStoppingCallback(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs=None):
        train_accuracy = logs.get('binary_accuracy')
        val_accuracy = logs.get('val_binary_accuracy')

        if train_accuracy >= 0.95 and val_accuracy >= 0.85:
            self.model.stop_training = True
            print("\nReached 95% train accuracy and 85% validation accuracy, so cancelling training!")

# %%
epoch = 1000
history = model.fit(train_generator, 
                    batch_size=BATCH_SIZE, 
                    epochs=epoch, 
                    validation_data=validation_generator, 
                    shuffle=True,
                    callbacks=[EarlyStoppingCallback(), early_stopping, reduce_lr])
# Out:
# Epoch 1/1000
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 64s 942ms/step - binary_accuracy: 0.8313 - loss: 0.4860 - val_binary_accuracy: 0.8571 - val_loss: 0.4120 - learning_rate: 0.0010
# Epoch 2/1000
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - binary_accuracy: 0.8571 - loss: 0.4158 - val_binary_accuracy: 0.8571 - val_loss: 0.4123 - learning_rate: 0.0010
# Epoch 3/1000
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 55s 844ms/step - binary_accuracy: 0.8571 - loss: 0.4168 - val_binary_accuracy: 0.8571 - val_loss: 0.4102 - learning_rate: 0.0010
# Epoch 4/1000
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 56s 856ms/step - binary_accuracy: 0.8571 - loss: 0.4124 - val_binary_accuracy: 0.8571 - val_loss: 0.4085 - learning_rate: 0.0010
# Epoch 5/1000
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 53s 822ms/step - binary_accuracy: 0.8571 - loss: 0.4065 - val_binary_accuracy: 0.8571 - val_loss: 0.3702 - learning_rate: 0.0010
# Epoch 6/1000
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 54s 839ms/step - binary_accuracy: 0.8569 - loss: 0.3815 - val_binary_accuracy: 0.8571 - val_loss: 0.3514 - learning_rate: 0.0010
# Epoch 7/1000
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 63s 971ms/step - binary_accuracy: 0.8561 - loss: 0.3763 - val_binary_accuracy: 0.8566 - val_loss: 0.3409 - learning_rate: 0.0010
# Epoch 8/1000
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 54s 835ms/step - binary_accuracy: 0.8547 - loss: 0.3559 - val_binary_accuracy: 0.8568 - val_loss: 0.3604 - learning_rate: 0.0010
# Epoch 9/1000
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 50s 772ms/step - binary_accuracy: 0.8554 - loss: 0.3533 - val_binary_accuracy: 0.8583 - val_loss: 0.3314 - learning_rate: 0.0010
# Epoch 10/1000
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 55s 847ms/step - binary_accuracy: 0.8564 - loss: 0.3512 - val_binary_accuracy: 0.8583 - val_loss: 0.3169 - learning_rate: 0.0010
# Epoch 11/1000
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - binary_accuracy: 0.8569 - loss: 0.3363 - val_binary_accuracy: 0.8586 - val_loss: 0.3194 - learning_rate: 0.0010
# Epoch 12/1000
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 71s 1s/step - binary_accuracy: 0.8543 - loss: 0.3325 - val_binary_accuracy: 0.8568 - val_loss: 0.3203 - learning_rate: 0.0010
# Epoch 13/1000
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 56s 855ms/step - binary_accuracy: 0.8568 - loss: 0.3448 - val_binary_accuracy: 0.8583 - val_loss: 0.3047 - learning_rate: 0.0010
# Epoch 14/1000
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 64s 987ms/step - binary_accuracy: 0.8570 - loss: 0.3241 - val_binary_accuracy: 0.8595 - val_loss: 0.3248 - learning_rate: 0.0010
# Epoch 15/1000
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 64s 976ms/step - binary_accuracy: 0.8572 - loss: 0.3208 - val_binary_accuracy: 0.8598 - val_loss: 0.2990 - learning_rate: 0.0010
# Epoch 16/1000
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - binary_accuracy: 0.8601 - loss: 0.3153 - val_binary_accuracy: 0.8598 - val_loss: 0.2995 - learning_rate: 0.0010
# Epoch 17/1000
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 56s 866ms/step - binary_accuracy: 0.8576 - loss: 0.3178 - val_binary_accuracy: 0.8595 - val_loss: 0.2936 - learning_rate: 0.0010
# Epoch 18/1000
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 57s 883ms/step - binary_accuracy: 0.8601 - loss: 0.3057 - val_binary_accuracy: 0.8592 - val_loss: 0.2984 - learning_rate: 0.0010
# Epoch 19/1000
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 56s 867ms/step - binary_accuracy: 0.8574 - loss: 0.3183 - val_binary_accuracy: 0.8648 - val_loss: 0.2919 - learning_rate: 0.0010
# Epoch 20/1000
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - binary_accuracy: 0.8565 - loss: 0.3149 - val_binary_accuracy: 0.8630 - val_loss: 0.2869 - learning_rate: 0.0010
# Epoch 21/1000
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 56s 853ms/step - binary_accuracy: 0.8591 - loss: 0.3022 - val_binary_accuracy: 0.8607 - val_loss: 0.2904 - learning_rate: 0.0010
# Epoch 22/1000
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 55s 852ms/step - binary_accuracy: 0.8613 - loss: 0.3047 - val_binary_accuracy: 0.8624 - val_loss: 0.3097 - learning_rate: 0.0010
# Epoch 23/1000
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 55s 840ms/step - binary_accuracy: 0.8611 - loss: 0.3002 - val_binary_accuracy: 0.8703 - val_loss: 0.2838 - learning_rate: 0.0010
# Epoch 24/1000
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 55s 853ms/step - binary_accuracy: 0.8574 - loss: 0.3205 - val_binary_accuracy: 0.8630 - val_loss: 0.2881 - learning_rate: 0.0010
# Epoch 25/1000
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 62s 952ms/step - binary_accuracy: 0.8603 - loss: 0.2963 - val_binary_accuracy: 0.8651 - val_loss: 0.2842 - learning_rate: 0.0010
# Epoch 26/1000
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 58s 899ms/step - binary_accuracy: 0.8607 - loss: 0.3051 - val_binary_accuracy: 0.8674 - val_loss: 0.2780 - learning_rate: 0.0010
# Epoch 27/1000
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 65s 1000ms/step - binary_accuracy: 0.8597 - loss: 0.2962 - val_binary_accuracy: 0.8665 - val_loss: 0.2824 - learning_rate: 0.0010
# Epoch 28/1000
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 54s 838ms/step - binary_accuracy: 0.8633 - loss: 0.2916 - val_binary_accuracy: 0.8645 - val_loss: 0.2759 - learning_rate: 0.0010
# Epoch 29/1000
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 55s 848ms/step - binary_accuracy: 0.8671 - loss: 0.2896 - val_binary_accuracy: 0.8659 - val_loss: 0.2716 - learning_rate: 0.0010
# Epoch 30/1000
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 57s 883ms/step - binary_accuracy: 0.8662 - loss: 0.2868 - val_binary_accuracy: 0.8654 - val_loss: 0.2745 - learning_rate: 0.0010
# Epoch 31/1000
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 56s 852ms/step - binary_accuracy: 0.8677 - loss: 0.2837 - val_binary_accuracy: 0.8709 - val_loss: 0.2655 - learning_rate: 0.0010
# Epoch 32/1000
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 63s 967ms/step - binary_accuracy: 0.8667 - loss: 0.2802 - val_binary_accuracy: 0.8747 - val_loss: 0.2678 - learning_rate: 0.0010
# Epoch 33/1000
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 71s 1s/step - binary_accuracy: 0.8632 - loss: 0.2969 - val_binary_accuracy: 0.8844 - val_loss: 0.2488 - learning_rate: 0.0010
# Epoch 34/1000
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 62s 951ms/step - binary_accuracy: 0.8740 - loss: 0.2698 - val_binary_accuracy: 0.8821 - val_loss: 0.2535 - learning_rate: 0.0010
# Epoch 35/1000
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 56s 854ms/step - binary_accuracy: 0.8726 - loss: 0.2800 - val_binary_accuracy: 0.8827 - val_loss: 0.2508 - learning_rate: 0.0010
# Epoch 36/1000
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - binary_accuracy: 0.8761 - loss: 0.2646 - val_binary_accuracy: 0.8833 - val_loss: 0.2625 - learning_rate: 0.0010
# Epoch 37/1000
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - binary_accuracy: 0.8802 - loss: 0.2636 - val_binary_accuracy: 0.8906 - val_loss: 0.2314 - learning_rate: 1.0000e-04
# Epoch 38/1000
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 57s 872ms/step - binary_accuracy: 0.8801 - loss: 0.2491 - val_binary_accuracy: 0.8950 - val_loss: 0.2321 - learning_rate: 1.0000e-04
# Epoch 39/1000
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 57s 871ms/step - binary_accuracy: 0.8828 - loss: 0.2524 - val_binary_accuracy: 0.8929 - val_loss: 0.2309 - learning_rate: 1.0000e-04
# Epoch 40/1000
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 57s 882ms/step - binary_accuracy: 0.8838 - loss: 0.2523 - val_binary_accuracy: 0.8912 - val_loss: 0.2272 - learning_rate: 1.0000e-04
# Epoch 41/1000
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 59s 907ms/step - binary_accuracy: 0.8843 - loss: 0.2492 - val_binary_accuracy: 0.8932 - val_loss: 0.2285 - learning_rate: 1.0000e-04
# Epoch 42/1000
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 60s 932ms/step - binary_accuracy: 0.8853 - loss: 0.2527 - val_binary_accuracy: 0.8965 - val_loss: 0.2251 - learning_rate: 1.0000e-04
# Epoch 43/1000
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 61s 942ms/step - binary_accuracy: 0.8870 - loss: 0.2433 - val_binary_accuracy: 0.8959 - val_loss: 0.2267 - learning_rate: 1.0000e-04
# Epoch 44/1000
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - binary_accuracy: 0.8883 - loss: 0.2426 - val_binary_accuracy: 0.8970 - val_loss: 0.2258 - learning_rate: 1.0000e-04
# Epoch 45/1000
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 69s 1s/step - binary_accuracy: 0.8844 - loss: 0.2456 - val_binary_accuracy: 0.8935 - val_loss: 0.2271 - learning_rate: 1.0000e-04
# Epoch 46/1000
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - binary_accuracy: 0.8888 - loss: 0.2420 - val_binary_accuracy: 0.8970 - val_loss: 0.2239 - learning_rate: 1.0000e-05
# Epoch 47/1000
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 63s 968ms/step - binary_accuracy: 0.8868 - loss: 0.2443 - val_binary_accuracy: 0.8982 - val_loss: 0.2238 - learning_rate: 1.0000e-05
# Epoch 48/1000
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 63s 965ms/step - binary_accuracy: 0.8873 - loss: 0.2406 - val_binary_accuracy: 0.8956 - val_loss: 0.2243 - learning_rate: 1.0000e-05
# Epoch 49/1000
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - binary_accuracy: 0.8853 - loss: 0.2506 - val_binary_accuracy: 0.8953 - val_loss: 0.2248 - learning_rate: 1.0000e-05
# Epoch 50/1000
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 56s 863ms/step - binary_accuracy: 0.8866 - loss: 0.2486 - val_binary_accuracy: 0.8982 - val_loss: 0.2239 - learning_rate: 1.0000e-05
# Epoch 51/1000
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 64s 987ms/step - binary_accuracy: 0.8856 - loss: 0.2538 - val_binary_accuracy: 0.8979 - val_loss: 0.2237 - learning_rate: 1.0000e-06
# Epoch 52/1000
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 61s 943ms/step - binary_accuracy: 0.8899 - loss: 0.2384 - val_binary_accuracy: 0.8976 - val_loss: 0.2236 - learning_rate: 1.0000e-06
# Epoch 53/1000
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 62s 948ms/step - binary_accuracy: 0.8829 - loss: 0.2489 - val_binary_accuracy: 0.8973 - val_loss: 0.2236 - learning_rate: 1.0000e-06
# Epoch 54/1000
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - binary_accuracy: 0.8878 - loss: 0.2448 - val_binary_accuracy: 0.8970 - val_loss: 0.2235 - learning_rate: 1.0000e-06
# Epoch 55/1000
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 64s 768ms/step - binary_accuracy: 0.8878 - loss: 0.2441 - val_binary_accuracy: 0.8967 - val_loss: 0.2235 - learning_rate: 1.0000e-06
# Epoch 56/1000
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 50s 773ms/step - binary_accuracy: 0.8881 - loss: 0.2426 - val_binary_accuracy: 0.8967 - val_loss: 0.2235 - learning_rate: 1.0000e-06
# Epoch 57/1000
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 57s 881ms/step - binary_accuracy: 0.8865 - loss: 0.2519 - val_binary_accuracy: 0.8970 - val_loss: 0.2234 - learning_rate: 1.0000e-06
# Epoch 58/1000
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 58s 895ms/step - binary_accuracy: 0.8878 - loss: 0.2409 - val_binary_accuracy: 0.8973 - val_loss: 0.2235 - learning_rate: 1.0000e-06
# Epoch 59/1000
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 50s 764ms/step - binary_accuracy: 0.8899 - loss: 0.2442 - val_binary_accuracy: 0.8973 - val_loss: 0.2236 - learning_rate: 1.0000e-06
# Epoch 60/1000
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 57s 885ms/step - binary_accuracy: 0.8887 - loss: 0.2433 - val_binary_accuracy: 0.8967 - val_loss: 0.2235 - learning_rate: 1.0000e-06
# Epoch 61/1000
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 56s 858ms/step - binary_accuracy: 0.8885 - loss: 0.2447 - val_binary_accuracy: 0.8973 - val_loss: 0.2236 - learning_rate: 1.0000e-06
# Epoch 62/1000
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - binary_accuracy: 0.8910 - loss: 0.2397 - val_binary_accuracy: 0.8976 - val_loss: 0.2235 - learning_rate: 1.0000e-06

# %%
ds = validation_generator
print("Test Accuracy", model.evaluate(ds)[1])
# Out:
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 7s 402ms/step - binary_accuracy: 0.8948 - loss: 0.2237
# Test Accuracy 0.8970373868942261

# %%
print("Loss Accuracy", model.evaluate(ds)[0])
# Out:
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 7s 402ms/step - binary_accuracy: 0.8901 - loss: 0.2261
# Loss Accuracy 0.22344832122325897

# %%
train_loss=history.history['loss']
val_loss=history.history['val_loss']

train_acc= history.history['binary_accuracy']
val_acc= history.history['val_binary_accuracy']

# %%
plt.plot(history.history['binary_accuracy'])
plt.plot(history.history['val_binary_accuracy'])
plt.title("model accuracy")
plt.ylabel('binary_accuracy')
plt.xlabel('epoch')
plt.legend(["Train", 'Validation'], loc='upper left')
plt.show()


plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title("model loss")
plt.ylabel("loss")
plt.xlabel('epoch')
plt.legend(["Train", 'Validation'], loc='upper left')
plt.show()
